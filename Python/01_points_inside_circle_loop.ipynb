# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# A simple function to check if a point lies inside a circle
def inside(point, circle_ctx, circle_radius):
    return (point[0] - circle_ctx[0]) ** 2 + (point[1] - circle_ctx[1]) ** 2 <= (circle_radius ** 2)

# %%
# Generate some random Points
num_points = 20
points = np.random.uniform(-6, 6, (num_points, 2))

# A circle with 1,1 centre and a certain radius
circle_ctx = (1, 1)
circle_radius = 4

# Creates a figure and one subplot
fig, ax = plt.subplots()

# Plot the circle
ax.add_patch(plt.Circle(circle_ctx, circle_radius, color='b', alpha=0.1))

for pt in points:

    # Check if the point lies inside or outside the circle
    result = inside(pt, circle_ctx, circle_radius)
    if result:
        ax.scatter(pt[0], pt[1], c='green') # Green if inside
        print(f"{pt} inside the circle")
    else:
        ax.scatter(pt[0], pt[1], c='red', marker = 'x') # Red if outside
        print(f"{pt} outside the circle")

# Show the plot
ax.set_aspect('equal', adjustable='datalim')
plt.show()
# Out:
# [-2.33154292 -4.60862129] outside the circle
# [1.41254039 4.18102354] inside the circle
# [ 3.74019956 -2.87675607] outside the circle
# [-4.53593278  4.64625145] outside the circle
# [ 4.93417917 -1.19797694] outside the circle
# [0.13139582 1.65484243] inside the circle
# [-2.17066865 -4.45773362] outside the circle
# [2.65746316 3.0169438 ] inside the circle
# [-0.29725439 -1.85718465] inside the circle
# [-2.78381658 -3.20691141] outside the circle
# [-3.51458289  5.49295576] outside the circle
# [ 3.96524775 -0.37619316] inside the circle
# [1.627464   2.61328286] inside the circle
# [2.81872111 3.82008954] inside the circle
# [3.79108607 5.60726475] outside the circle
# [ 5.7300115  -4.71196204] outside the circle
# [-3.79353663  0.92652876] outside the circle
# [ 5.34728651 -1.37191905] outside the circle
# [-5.56319713  1.83785122] outside the circle
# [ 1.44177185 -4.06353365] outside the circle
