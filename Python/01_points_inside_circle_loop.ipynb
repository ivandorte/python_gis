# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# A simple function to check if a point lies inside a circle
def inside(point, circle_ctx, circle_radius):
    return (point[0] - circle_ctx[0]) ** 2 + (point[1] - circle_ctx[1]) ** 2 <= (circle_radius ** 2)

# %%
# Generate some random Points
num_points = 20
points = np.random.uniform(-6, 6, (num_points, 2))

# A circle with 1,1 centre and a certain radius
circle_ctx = (1, 1)
circle_radius = 4

# Creates a figure and one subplot
fig, ax = plt.subplots()

# Plot the circle
ax.add_patch(plt.Circle(circle_ctx, circle_radius, color='b', alpha=0.1))

for pt in points:

    # Check if the point lies inside or outside the circle
    result = inside(pt, circle_ctx, circle_radius)
    if result:
        ax.scatter(pt[0], pt[1], c='green') # Green if inside
        print(f"{pt} inside the circle")
    else:
        ax.scatter(pt[0], pt[1], c='red', marker = 'x') # Red if outside
        print(f"{pt} outside the circle")

# Show the plot
ax.set_aspect('equal', adjustable='datalim')
plt.show()
# Out:
# [-1.61114035  2.83498825] inside the circle
# [1.81731692 5.16926082] outside the circle
# [-4.71579079  4.17773196] outside the circle
# [-2.68864257 -4.3276318 ] outside the circle
# [ 1.05399513 -0.96189466] inside the circle
# [4.63010127 1.09245011] inside the circle
# [ 3.8268423  -0.08736544] inside the circle
# [-0.83615693 -3.12547533] outside the circle
# [-4.76751366 -5.77755351] outside the circle
# [-2.35923346  0.37895761] inside the circle
# [2.61807803 5.8477914 ] outside the circle
# [-2.36421644  0.93283403] inside the circle
# [ 5.41411277 -2.99839903] outside the circle
# [-1.68453415 -1.37710582] inside the circle
# [1.00926483 3.53837212] inside the circle
# [ 5.60611716 -4.11779049] outside the circle
# [-2.20791777 -0.25751517] inside the circle
# [-2.04783412 -3.69798772] outside the circle
# [-3.2980682  -2.98878079] outside the circle
# [ 3.13625822 -0.11948939] inside the circle
